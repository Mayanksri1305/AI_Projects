# %% [markdown]
# ## Equal weights strategy

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import math

# %%
tickers = pd.read_csv('top_50_indian_stocks.csv')
tickers.head()
# Out:
#          Ticker               Company Name
# 0   RELIANCE.NS        Reliance Industries
# 1        TCS.NS  Tata Consultancy Services
# 2   HDFCBANK.NS                  HDFC Bank
# 3       INFY.NS                    Infosys
# 4  ICICIBANK.NS                 ICICI Bank

# %%
def fetch_market_cap(tickers_list):
    data = yf.download(tickers_list, period='1d', group_by='ticker', auto_adjust=False)
    return data

tickers_list = tickers["Ticker"].values.tolist()
fetch_market_cap(tickers_list)
fetch_market_cap(tickers_list)
# Out:
# [**********************46%                       ]  23 of 50 completed$TATAMOTORS.NS: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [*********************100%***********************]  50 of 50 completed
#
# 1 Failed download:
# ['TATAMOTORS.NS']: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [********************* 44%                       ]  22 of 50 completed$TATAMOTORS.NS: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [*********************100%***********************]  50 of 50 completed
#
# 1 Failed download:
# ['TATAMOTORS.NS']: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# Ticker         DMART.NS                                                 \
# Price              Open    High          Low   Close Adj Close  Volume
# Date
# 2026-06-29  4290.100098  4385.0  4277.700195  4357.0    4357.0  722144
#
# Ticker     HDFCAMC.NS                                         ...  SBICARD.NS  \
# Price            Open         High          Low        Close  ...         Low
# Date                                                          ...
# 2026-06-29     2638.0  2679.899902  2594.399902  2606.600098  ...  600.200012
#
# Ticker                                       AXISBANK.NS               \
# Price            Close   Adj Close   Volume         Open         High
# Date
# 2026-06-29  601.900024  601.900024  3441148  1392.599976  1392.599976
#
# Ticker
# Price               Low        Close    Adj Close    Volume
# Date
# 2026-06-29  1352.199951  1356.800049  1356.800049  12601030
#
# [1 rows x 300 columns]

# %%
def fetch_market_cap(ticker_list) :
    data = yf.download(ticker_list, period='1d', group_by='ticker', auto_adjust=False)

    stock_data = {}
    for ticker in ticker_list:
        def fetch_market_cap(ticker_list):
            data = yf.download(ticker_list, period='1d', group_by='ticker', auto_adjust=False)

            stocks_data = []
            for ticker in ticker_list:
                latest_price = data[ticker]['Close'].iloc[-1]
                market_cap = yf.Ticker(ticker).info.get('marketCap', None)
                stocks_data.append({
                    "Ticker": ticker,
                    "Latest Price": latest_price,
                    "Market Cap": market_cap
                })

            stocks_df = pd.DataFrame(stocks_data)
            return stocks_df

        ticker_list = tickers["Ticker"].values.tolist()
        df = fetch_market_cap(ticker_list)
        df
        market_cap= yf.Ticker(ticker).info.get('marketCap', None)
        stocks_data.append({
            "Ticker" : ticker,
            "Latest Price" : latest_price,
            "Market Cap" : market_cap
        })
        stocks_df= pd.DataFrame(stocks_data)

        return stocks_df
    ticker_list = tickers["Ticker"].values.tolist()
    df = fetch_market_cap(ticker_list)
    df
# Out:
#   Cell In[59], line 6
#     latest price = data[ticker]['Close'].iloc[-1]
#            ^
# SyntaxError: invalid syntax
